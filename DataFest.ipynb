# %%
import pandas as pd

# %%
df_departments = pd.read_csv('departments.csv')
df_departments.dtypes
# Out:
# DepartmentKey            int64
# Address                 object
# City                    object
# County                  object
# DepartmentName          object
# DepartmentSpecialty     object
# DepartmentType          object
# PostalCode              object
# CensusTract            float64
# dtype: object
